# %% [markdown]
# # Ejercicio 1: Introducción a Recuperación de Información
#
# ## Objetivo de la práctica
# - Entender el problema de **buscar información** en colecciones de texto.
# - Comprender por qué se necesita un **índice invertido** en recuperación de información.
# - Programar una primera solución manual y luego optimizarla con un índice.
# - Evaluar la mejora en tiempos de búsqueda cuando usamos estructuras adecuadas.

# %% [markdown]
# ## Parte 1: Búsqueda lineal en documentos
#
# ### Actividad
# 1. Se te proporcionará un conjunto de documentos de texto.
# 2. Escribe una función que:
#    - Lea todos los documentos.
#    - Busque una palabra ingresada por el usuario.
#    - Muestre en qué documentos aparece la palabra.

# %%
file = open("01_corpus_turismo.txt", "r")
lines = file.readlines()
lines = [lines.strip() for lines in lines]

results = []

query = "la"

for i, doc in enumerate(lines):
    if query in doc:
        results.append((i, doc))  

for i, text in results:
    print(f"results {i}: {text}")
# Out:
# results 0: Ecuador es un paÃ­s megadiverso, con playas, montaÃ±as y selvas ideales para el turismo ecolÃ³gico.
# results 1: Las Islas GalÃ¡pagos atraen visitantes de todo el mundo por su biodiversidad Ãºnica.
# results 2: La ciudad de Quito cuenta con un centro histÃ³rico declarado Patrimonio de la Humanidad por la UNESCO.
# results 4: La Ruta del Spondylus conecta playas famosas como MontaÃ±ita, Salinas y Puerto LÃ³pez.
# results 7: El volcÃ¡n Cotopaxi ofrece a los excursionistas una de las ascensiones mÃ¡s impresionantes de los Andes.
# results 8: Mindo es un paraÃ­so para el avistamiento de aves y la exploraciÃ³n de bosques nublados.
# results 9: Guayaquil sorprende con su MalecÃ³n 2000, su vida nocturna y su cercanÃ­a a las playas del PacÃ­fico.
# results 11: En el feriado, muchos ecuatorianos visitan la AmazonÃ­a para conocer comunidades indÃ­genas y cascadas.
# results 12: El Parque Nacional Cajas invita a los turistas a caminatas entre lagunas y pÃ¡ramos a gran altitud.
# results 13: Los turistas disfrutan en el feriado de las fiestas locales y de la gastronomÃ­a tÃ­pica de cada regiÃ³n.
# results 14: Vilcabamba, conocido como el Valle de la Longevidad, atrae visitantes interesados en el bienestar y la naturaleza.

# %% [markdown]
# ## Parte 2: Construcción de un índice invertido
#
# ### Actividad
# 1. Escribe un programa que:
#    - Recorra todos los documentos.
#    - Construya un **índice invertido**, es decir, un diccionario donde:
#      - Cada palabra clave apunta a una lista de documentos donde aparece.
#
# 2. Escribe una nueva función de búsqueda que:
#    - Consulte directamente el índice para encontrar los documentos relevantes.
#    - Sea mucho más rápida que la búsqueda lineal.

# %%
file = open("01_corpus_turismo.txt", "r")
lines = file.readlines()
lines = [lines.strip() for lines in lines]

inverted_index = {}

query = "de"

for i, doc in enumerate(lines):
    words = doc.split()
    for word in words:
        if word not in inverted_index:
            inverted_index[word] = []
        if i not in inverted_index[word]:
            inverted_index[word].append(i)

answer = inverted_index.get(query)

print(answer)
# Out:
# [1, 2, 3, 7, 8, 10, 13, 14, 15]

# %% [markdown]
# ## Parte 3: Evaluación de tiempos de búsqueda
# ### Actividad
#
# 1. Realiza la búsqueda de varias palabras usando:
#       -  Corpus pequeño: 16 documentos (turismo en Ecuador).
#       -  Corpus grande: 500 documentos (versión ampliada).
# 2. Mide el tiempo de ejecución:
#       -  Para búsqueda lineal.
#       -  Para búsqueda usando índice invertido.
#       -  Grafica o presenta los resultados en una tabla comparativa.
#
# ### Ejemplo de palabras para buscar
# - quito
# - montañita
# - feriado
# - playas
# - aventura
# - galápagos

# %%
import time
import pandas as pd

short_file = open("01_corpus_turismo.txt", "r", encoding="utf-8")
lines_short_file = short_file.readlines()
lines_short_file = [lines_short_file.strip() for lines_short_file in lines_short_file]

long_file = open("01_corpus_turismo_500.txt", "r", encoding="utf-8")
lines_long_file = long_file.readlines()
lines_long_file = [lines_long_file.strip() for lines_long_file in lines_long_file]

query_array = ["Quito", "Montañita", "feriado", "playas", "aventura", "Galápagos"]

# Función de búsqueda lineal
def linear_search(corpus, query):
    results = []
    for i, doc in enumerate(corpus):
        if query in doc:
            results.append((i, doc))
    return results

# Función para construir índice invertido
def build_inverted_index(corpus):
    inverted_index = {}
    for i, doc in enumerate(corpus):
        words = doc.split()
        for word in words:
            if word not in inverted_index:
                inverted_index[word] = []
            if i not in inverted_index[word]:
                inverted_index[word].append(i)
    return inverted_index

# Función de búsqueda usando índice invertido
def inverted_search(index, query):
    return index.get(query, [])

#####################
#Ejecución del corpus pequeño

print("BÚSQUEDA LINEAL en Corpus Pequeño:\n")
for query in query_array:
    print(query)
    results = linear_search(lines_short_file, query)
    for i, text in results:
        print(f"results {i}: {text}", "\n")

print("\nBÚSQUEDA ÍNDICE INVERTIDO en Corpus Pequeño:\n")
inverted_index_short_file = build_inverted_index(lines_short_file)
for query in query_array:
    print(query)
    answer = inverted_search(inverted_index_short_file, query)
    print(answer, "\n")


#####################
# Ejecución del corpus grande

print("BÚSQUEDA LINEAL en Corpus Grande:\n")
for query in query_array:
    print(query)
    results = linear_search(lines_long_file, query)
    for i, text in results:
        print(f"results {i}: {text}", "\n")

print("\nBÚSQUEDA ÍNDICE INVERTIDO en Corpus Grande:\n")
inverted_index_long_file = build_inverted_index(lines_long_file)
for query in query_array:
    print(query)
    answer = inverted_search(inverted_index_long_file, query)
    print(answer, "\n")


########################
# Medición del tiempo

def measure_time(corpus, query_array, corpus_type, index=None):
    results = []
    for query in query_array:
        # Medición de tiempo para la búsqueda lineal
        start_time = time.perf_counter()
        linear_results = linear_search(corpus, query)
        linear_time = time.perf_counter() - start_time
        
        # Medición de tiempo para la búsqueda con índice invertido
        start_time = time.perf_counter()
        inverted_results = inverted_search(index, query) if index else []
        inverted_time = time.perf_counter() - start_time
        
        results.append({
            "Query": query,  
            "Corpus": corpus_type, 
            "Linear Search Time (s)": linear_time,
            "Inverted Search Time (s)": inverted_time
        })
    return results

# Crear los índices invertidos para cada corpus
inverted_index_short_file = build_inverted_index(lines_short_file)
inverted_index_long_file = build_inverted_index(lines_long_file)

# Medir el tiempo en el corpus pequeño
short_corpus_results = measure_time(lines_short_file, query_array, "Corpus Pequeño", inverted_index_short_file)

# Medir el tiempo en el corpus grande
long_corpus_results = measure_time(lines_long_file, query_array, "Corpus Grande", inverted_index_long_file)

# Combinar los resultados en un solo dataframe
all_results = short_corpus_results + long_corpus_results
df_results = pd.DataFrame(all_results)

# Imprimir la tabla comparativa
print(df_results)
# Out:
# BÚSQUEDA LINEAL en Corpus Pequeño:
#
# Quito
# results 2: La ciudad de Quito cuenta con un centro histórico declarado Patrimonio de la Humanidad por la UNESCO.
#
# Montañita
# results 4: La Ruta del Spondylus conecta playas famosas como Montañita, Salinas y Puerto López.
#
# results 15: Montañita se llena de surfistas y viajeros jóvenes durante los feriados nacionales.
#
# feriado
# results 11: En el feriado, muchos ecuatorianos visitan la Amazonía para conocer comunidades indígenas y cascadas.
#
# results 13: Los turistas disfrutan en el feriado de las fiestas locales y de la gastronomía típica de cada región.
#
# results 15: Montañita se llena de surfistas y viajeros jóvenes durante los feriados nacionales.
#
# playas
# results 0: Ecuador es un país megadiverso, con playas, montañas y selvas ideales para el turismo ecológico.
#
# results 4: La Ruta del Spondylus conecta playas famosas como Montañita, Salinas y Puerto López.
#
# results 9: Guayaquil sorprende con su Malecón 2000, su vida nocturna y su cercanía a las playas del Pacífico.
#
# aventura
# results 3: En Baños de Agua Santa, los turistas disfrutan de deportes de aventura como rafting y canopy.
#
# Galápagos
# results 1: Las Islas Galápagos atraen visitantes de todo el mundo por su biodiversidad única.
#
#
# BÚSQUEDA ÍNDICE INVERTIDO en Corpus Pequeño:
#
# Quito
# [2]
#
# Montañita
# [15]
#
# feriado
# [13]
#
# playas
# [4, 9]
#
# aventura
# [3]
#
# Galápagos
# [1]
#
# BÚSQUEDA LINEAL en Corpus Grande:
#
# Quito
# results 3: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para surf.
#
# results 15: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 16: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar sorprendente para visitar.
#
# results 38: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para rafting.
#
# results 42: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para senderismo.
#
# results 72: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 74: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 88: Quito tiene un centro histórico Patrimonio de la Humanidad
#
# results 103: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para canopy.
#
# results 135: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para canopy.
#
# results 200: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar sorprendente para visitar.
#
# results 212: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 237: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para senderismo.
#
# results 259: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar auténtico para visitar.
#
# results 290: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para rafting.
#
# results 324: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 354: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para surf.
#
# results 390: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar tranquilo para visitar.
#
# results 468: Quito tiene un centro histórico Patrimonio de la Humanidad
#
# results 486: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# Montañita
# results 19: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 27: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 35: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 50: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 66: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 68: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 78: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 82: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 86: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 87: Montañita se llena de surfistas durante los feriados Un lugar espectacular para visitar.
#
# results 95: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 99: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para senderismo.
#
# results 102: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 106: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 119: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 123: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 125: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 134: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 145: Montañita se llena de surfistas durante los feriados
#
# results 150: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 163: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para surf.
#
# results 169: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 177: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 184: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 197: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 204: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 208: Montañita se llena de surfistas durante los feriados Perfecto para rafting.
#
# results 210: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 218: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 228: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 232: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 234: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 235: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 238: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 243: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 265: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 267: Montañita se llena de surfistas durante los feriados
#
# results 272: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 276: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 297: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 298: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar famoso para visitar.
#
# results 299: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 311: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 315: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 317: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 320: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 321: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 322: Montañita se llena de surfistas durante los feriados
#
# results 326: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 327: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 369: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 380: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 383: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 386: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 389: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 395: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 402: Montañita se llena de surfistas durante los feriados
#
# results 404: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 405: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 408: Montañita se llena de surfistas durante los feriados
#
# results 412: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 416: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 418: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 421: Montañita se llena de surfistas durante los feriados
#
# results 422: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 429: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 449: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 450: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 466: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 475: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 479: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 482: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 492: Montañita se llena de surfistas durante los feriados Perfecto para senderismo.
#
# results 493: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# feriado
# results 8: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 9: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 11: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 15: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 26: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para rafting.
#
# results 29: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 31: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 32: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 33: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 34: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 35: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 39: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 43: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar increíble para visitar.
#
# results 49: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 55: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 64: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 65: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 69: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 72: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 74: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 78: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 79: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 87: Montañita se llena de surfistas durante los feriados Un lugar espectacular para visitar.
#
# results 90: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 105: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 106: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 107: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 108: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 109: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 112: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para rafting.
#
# results 115: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 122: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 123: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 125: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 129: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 131: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para avistamiento de aves.
#
# results 132: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 133: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 137: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 138: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 145: Montañita se llena de surfistas durante los feriados
#
# results 146: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 147: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 152: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para surf.
#
# results 153: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 154: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 156: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 161: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 165: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 166: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar auténtico para visitar.
#
# results 167: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 169: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 177: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 178: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 180: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 184: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 188: Durante el feriado, muchos visitan la Amazonía ecuatoriana Una experiencia inolvidable.
#
# results 191: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 193: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 194: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 198: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 199: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 201: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 202: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 204: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 208: Montañita se llena de surfistas durante los feriados Perfecto para rafting.
#
# results 209: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 210: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 212: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 216: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 222: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 224: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 228: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 232: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 233: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 247: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 256: Durante el feriado, muchos visitan la Amazonía ecuatoriana Una experiencia inolvidable.
#
# results 261: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 266: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 267: Montañita se llena de surfistas durante los feriados
#
# results 268: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 270: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 279: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 280: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 281: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 285: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 294: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 299: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 302: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 305: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 307: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 308: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 309: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 310: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 311: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 314: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar sorprendente para visitar.
#
# results 315: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 317: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 320: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 322: Montañita se llena de surfistas durante los feriados
#
# results 324: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 327: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 328: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 330: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 332: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 336: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 339: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 341: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 343: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 345: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 350: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 353: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 359: Durante el feriado, muchos visitan la Amazonía ecuatoriana Una experiencia inolvidable.
#
# results 360: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 361: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 364: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 368: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 371: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 373: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 374: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 376: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 379: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 380: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 382: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 386: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 389: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 394: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 402: Montañita se llena de surfistas durante los feriados
#
# results 405: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 407: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 408: Montañita se llena de surfistas durante los feriados
#
# results 409: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 411: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 412: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 420: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 421: Montañita se llena de surfistas durante los feriados
#
# results 428: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 436: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 439: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 440: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 442: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 446: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 447: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 449: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 450: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 456: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 458: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 469: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 472: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 473: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 474: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar increíble para visitar.
#
# results 475: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 479: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 481: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 482: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 486: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 491: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 492: Montañita se llena de surfistas durante los feriados Perfecto para senderismo.
#
# results 493: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 494: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# playas
# results 19: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 27: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 35: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 50: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 66: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 68: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 78: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 82: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 86: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 95: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 99: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para senderismo.
#
# results 102: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 119: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 123: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 134: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 150: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 163: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para surf.
#
# results 169: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 197: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 218: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 228: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 232: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 234: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 235: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 238: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 243: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 265: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 272: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 276: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 297: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 298: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar famoso para visitar.
#
# results 320: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 321: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 326: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 327: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 369: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 383: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 389: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 395: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 404: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 405: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 416: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 418: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 422: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 429: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 466: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 479: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# aventura
# results 37: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar sorprendente para visitar.
#
# results 53: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar famoso para visitar.
#
# results 61: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 76: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar famoso para visitar.
#
# results 84: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 89: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# results 90: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 96: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para avistamiento de aves.
#
# results 98: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# results 201: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 248: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 254: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 275: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para senderismo.
#
# results 277: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 283: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 310: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 313: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 329: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 331: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 336: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 338: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 376: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 388: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para surf.
#
# results 391: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 407: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 438: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 480: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 483: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# results 484: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar famoso para visitar.
#
# results 489: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 497: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar tranquilo para visitar.
#
# results 499: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# Galápagos
# results 11: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 22: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 23: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 24: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 30: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 41: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 46: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar espectacular para visitar.
#
# results 80: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 83: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 93: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para rafting.
#
# results 124: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 127: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 138: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 172: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 226: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 242: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 287: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 294: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 303: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 305: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 307: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 337: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 349: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 358: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para rafting.
#
# results 393: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 398: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 442: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 457: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 460: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 463: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar tranquilo para visitar.
#
# results 465: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar espectacular para visitar.
#
# results 477: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 498: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para canopy.
#
#
# BÚSQUEDA ÍNDICE INVERTIDO en Corpus Grande:
#
# Quito
# [3, 15, 16, 38, 42, 72, 74, 88, 103, 135, 200, 212, 237, 259, 290, 324, 354, 390, 468, 486]
#
# Montañita
# [19, 27, 35, 50, 66, 68, 78, 82, 86, 87, 95, 99, 102, 106, 119, 123, 125, 134, 145, 150, 163, 169, 177, 184, 197, 204, 208, 210, 218, 228, 232, 234, 235, 238, 243, 265, 267, 272, 276, 297, 298, 299, 311, 315, 317, 320, 321, 322, 326, 327, 369, 380, 383, 386, 389, 395, 402, 404, 405, 408, 412, 416, 418, 421, 422, 429, 449, 450, 466, 475, 479, 482, 492, 493]
#
# feriado
# []
#
# playas
# [19, 27, 35, 50, 66, 68, 78, 82, 86, 95, 99, 102, 119, 123, 134, 150, 163, 169, 197, 218, 228, 232, 234, 235, 238, 243, 265, 272, 276, 297, 298, 320, 321, 326, 327, 369, 383, 389, 395, 404, 405, 416, 418, 422, 429, 466, 479]
#
# aventura
# [37, 53, 61, 76, 84, 89, 90, 96, 98, 201, 248, 254, 275, 277, 283, 310, 313, 329, 331, 336, 338, 376, 388, 391, 407, 438, 480, 483, 484, 489, 497, 499]
#
# Galápagos
# [11, 22, 23, 24, 30, 41, 46, 80, 83, 93, 124, 127, 138, 172, 226, 242, 287, 294, 303, 305, 307, 337, 349, 358, 393, 398, 442, 457, 460, 463, 465, 477, 498]
#
#         Query          Corpus  Linear Search Time (s)  \
# 0       Quito  Corpus Pequeño                0.000006
# 1   Montañita  Corpus Pequeño                0.000004
# 2     feriado  Corpus Pequeño                0.000003
# 3      playas  Corpus Pequeño                0.000003
# 4    aventura  Corpus Pequeño                0.000003
# 5   Galápagos  Corpus Pequeño                0.000003
# 6       Quito   Corpus Grande                0.000068
# 7   Montañita   Corpus Grande                0.000069
# 8     feriado   Corpus Grande                0.000085
# 9      playas   Corpus Grande                0.000061
# 10   aventura   Corpus Grande                0.000061
# 11  Galápagos   Corpus Grande                0.000057
#
#     Inverted Search Time (s)
# 0               2.300000e-06
# 1               8.999996e-07
# 2               1.100000e-06
# 3               6.000000e-07
# 4               6.000000e-07
# 5               6.000000e-07
# 6               6.999999e-07
# 7               5.000002e-07
# 8               5.000002e-07
# 9               5.000002e-07
# 10              6.000000e-07
# 11              7.999997e-07

# %% [markdown]
# ## Parte 4:
# ### Actividad
# 1. Modifica el índice para que ignore mayúsculas/minúsculas (por ejemplo, "Playa" y "playa" deben considerarse iguales).
# 2. Permite consultas de múltiples términos (ejemplo: buscar documentos que contengan "playa" y "turismo").
# 3. Calcula el _speedup_

# %%
import time
import pandas as pd

short_file = open("01_corpus_turismo.txt", "r", encoding="utf-8")
lines_short_file = short_file.readlines()
lines_short_file = [lines_short_file.strip() for lines_short_file in lines_short_file]

long_file = open("01_corpus_turismo_500.txt", "r", encoding="utf-8")
lines_long_file = long_file.readlines()
lines_long_file = [lines_long_file.strip() for lines_long_file in lines_long_file]

query_array = ["Quito", "Montañita", "feriado", "playas", "aventura", "Galápagos", "laguna destaca"] # Consulta múltiple "laguna destaca" 

# Función de búsqueda lineal 
def linear_search(corpus, query):
    results = []
    query_terms = query.lower().split() 
    for i, doc in enumerate(corpus):
        doc_lower = doc.lower()
        if all(term in doc_lower for term in query_terms):
            results.append((i, doc))
    return results

# Función para construir índice invertido 
def build_inverted_index(corpus):
    inverted_index = {}
    for i, doc in enumerate(corpus):
        words = doc.lower().split() 
        for word in words:
            if word not in inverted_index:
                inverted_index[word] = []
            if i not in inverted_index[word]:
                inverted_index[word].append(i)
    return inverted_index

# Función de búsqueda usando índice invertido 
def inverted_search(index, query):
    query_terms = query.lower().split()  
    result_sets = []
    for term in query_terms:
        result_sets.append(set(index.get(term, [])))
    
    if result_sets:
        common_docs = set.intersection(*result_sets) 
    else:
        common_docs = set()
    
    return list(common_docs)

#####################
# Ejecución del corpus pequeño

print("BÚSQUEDA LINEAL en Corpus Pequeño:\n")
for query in query_array:
    print(query)
    results = linear_search(lines_short_file, query)
    for i, text in results:
        print(f"results {i}: {text}", "\n")

print("\nBÚSQUEDA ÍNDICE INVERTIDO en Corpus Pequeño:\n")
inverted_index_short_file = build_inverted_index(lines_short_file)
for query in query_array:
    print(query)
    answer = inverted_search(inverted_index_short_file, query)
    print(answer, "\n")

#####################
# Ejecución del corpus grande

print("BÚSQUEDA LINEAL en Corpus Grande:\n")
for query in query_array:
    print(query)
    results = linear_search(lines_long_file, query)
    for i, text in results:
        print(f"results {i}: {text}", "\n")

print("\nBÚSQUEDA ÍNDICE INVERTIDO en Corpus Grande:\n")
inverted_index_long_file = build_inverted_index(lines_long_file)
for query in query_array:
    print(query)
    answer = inverted_search(inverted_index_long_file, query)
    print(answer, "\n")

########################
# Medición del tiempo

def measure_time(corpus, query_array, corpus_type, index=None):
    results = []
    for query in query_array:
        # Medición de tiempo para la búsqueda lineal
        start_time = time.perf_counter()
        linear_results = linear_search(corpus, query)
        linear_time = time.perf_counter() - start_time
        
        # Medición de tiempo para la búsqueda con índice invertido
        start_time = time.perf_counter()
        inverted_results = inverted_search(index, query) if index else []
        inverted_time = time.perf_counter() - start_time
        
        # Cálculo de speedup
        speedup = linear_time / inverted_time if inverted_time > 0 else float('inf')
        
        results.append({
            "Query": query,  
            "Corpus": corpus_type, 
            "Linear Search Time (s)": linear_time,
            "Inverted Search Time (s)": inverted_time,
            "Speedup": speedup
        })
    return results

# Crear los índices invertidos para cada corpus
inverted_index_short_file = build_inverted_index(lines_short_file)
inverted_index_long_file = build_inverted_index(lines_long_file)

# Medir el tiempo en el corpus pequeño
short_corpus_results = measure_time(lines_short_file, query_array, "Corpus Pequeño", inverted_index_short_file)

# Medir el tiempo en el corpus grande
long_corpus_results = measure_time(lines_long_file, query_array, "Corpus Grande", inverted_index_long_file)

# Combinar los resultados en un solo dataframe
all_results = short_corpus_results + long_corpus_results
df_results = pd.DataFrame(all_results)

# Imprimir la tabla comparativa
print(df_results)
# Out:
# BÚSQUEDA LINEAL en Corpus Pequeño:
#
# Quito
# results 2: La ciudad de Quito cuenta con un centro histórico declarado Patrimonio de la Humanidad por la UNESCO.
#
# Montañita
# results 4: La Ruta del Spondylus conecta playas famosas como Montañita, Salinas y Puerto López.
#
# results 15: Montañita se llena de surfistas y viajeros jóvenes durante los feriados nacionales.
#
# feriado
# results 11: En el feriado, muchos ecuatorianos visitan la Amazonía para conocer comunidades indígenas y cascadas.
#
# results 13: Los turistas disfrutan en el feriado de las fiestas locales y de la gastronomía típica de cada región.
#
# results 15: Montañita se llena de surfistas y viajeros jóvenes durante los feriados nacionales.
#
# playas
# results 0: Ecuador es un país megadiverso, con playas, montañas y selvas ideales para el turismo ecológico.
#
# results 4: La Ruta del Spondylus conecta playas famosas como Montañita, Salinas y Puerto López.
#
# results 9: Guayaquil sorprende con su Malecón 2000, su vida nocturna y su cercanía a las playas del Pacífico.
#
# aventura
# results 3: En Baños de Agua Santa, los turistas disfrutan de deportes de aventura como rafting y canopy.
#
# Galápagos
# results 1: Las Islas Galápagos atraen visitantes de todo el mundo por su biodiversidad única.
#
# laguna destaca
#
# BÚSQUEDA ÍNDICE INVERTIDO en Corpus Pequeño:
#
# Quito
# [2]
#
# Montañita
# [15]
#
# feriado
# [13]
#
# playas
# [9, 4]
#
# aventura
# [3]
#
# Galápagos
# [1]
#
# laguna destaca
# []
#
# BÚSQUEDA LINEAL en Corpus Grande:
#
# Quito
# results 3: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para surf.
#
# results 15: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 16: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar sorprendente para visitar.
#
# results 38: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para rafting.
#
# results 42: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para senderismo.
#
# results 72: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 74: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 88: Quito tiene un centro histórico Patrimonio de la Humanidad
#
# results 103: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para canopy.
#
# results 135: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para canopy.
#
# results 200: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar sorprendente para visitar.
#
# results 212: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 237: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para senderismo.
#
# results 259: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar auténtico para visitar.
#
# results 290: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para rafting.
#
# results 324: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 354: Quito tiene un centro histórico Patrimonio de la Humanidad Perfecto para surf.
#
# results 390: Quito tiene un centro histórico Patrimonio de la Humanidad Un lugar tranquilo para visitar.
#
# results 468: Quito tiene un centro histórico Patrimonio de la Humanidad
#
# results 486: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# Montañita
# results 19: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 27: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 35: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 50: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 66: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 68: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 78: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 82: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 86: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 87: Montañita se llena de surfistas durante los feriados Un lugar espectacular para visitar.
#
# results 95: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 99: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para senderismo.
#
# results 102: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 106: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 119: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 123: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 125: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 134: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 145: Montañita se llena de surfistas durante los feriados
#
# results 150: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 163: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para surf.
#
# results 169: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 177: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 184: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 197: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 204: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 208: Montañita se llena de surfistas durante los feriados Perfecto para rafting.
#
# results 210: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 218: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 228: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 232: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 234: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 235: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 238: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 243: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 265: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 267: Montañita se llena de surfistas durante los feriados
#
# results 272: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 276: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 297: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 298: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar famoso para visitar.
#
# results 299: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 311: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 315: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 317: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 320: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 321: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 322: Montañita se llena de surfistas durante los feriados
#
# results 326: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 327: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 369: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 380: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 383: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 386: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 389: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 395: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 402: Montañita se llena de surfistas durante los feriados
#
# results 404: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 405: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 408: Montañita se llena de surfistas durante los feriados
#
# results 412: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 416: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 418: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 421: Montañita se llena de surfistas durante los feriados
#
# results 422: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 429: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 449: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 450: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 466: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 475: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 479: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 482: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 492: Montañita se llena de surfistas durante los feriados Perfecto para senderismo.
#
# results 493: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# feriado
# results 8: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 9: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 11: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 15: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 26: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para rafting.
#
# results 29: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 31: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 32: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 33: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 34: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 35: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 39: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 43: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar increíble para visitar.
#
# results 49: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 55: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 64: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 65: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 69: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 72: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 74: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 78: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 79: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 87: Montañita se llena de surfistas durante los feriados Un lugar espectacular para visitar.
#
# results 90: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 105: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 106: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 107: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 108: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 109: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 112: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para rafting.
#
# results 115: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 122: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 123: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 125: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 129: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 131: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para avistamiento de aves.
#
# results 132: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 133: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 137: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 138: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 145: Montañita se llena de surfistas durante los feriados
#
# results 146: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 147: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 152: Durante el feriado, muchos visitan la Amazonía ecuatoriana Perfecto para surf.
#
# results 153: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 154: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 156: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 161: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 165: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 166: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar auténtico para visitar.
#
# results 167: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 169: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 177: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 178: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 180: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 184: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 188: Durante el feriado, muchos visitan la Amazonía ecuatoriana Una experiencia inolvidable.
#
# results 191: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 193: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 194: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 198: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 199: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 201: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 202: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 204: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 208: Montañita se llena de surfistas durante los feriados Perfecto para rafting.
#
# results 209: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 210: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 212: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 216: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 222: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 224: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 228: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 232: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 233: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 247: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 256: Durante el feriado, muchos visitan la Amazonía ecuatoriana Una experiencia inolvidable.
#
# results 261: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 266: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 267: Montañita se llena de surfistas durante los feriados
#
# results 268: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# results 270: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 279: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 280: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 281: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 285: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 294: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 299: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 302: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 305: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 307: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 308: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 309: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 310: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 311: Montañita se llena de surfistas durante los feriados Perfecto para surf.
#
# results 314: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar sorprendente para visitar.
#
# results 315: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 317: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 320: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 322: Montañita se llena de surfistas durante los feriados
#
# results 324: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 327: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 328: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 330: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 332: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 336: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 339: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 341: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 343: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 345: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 350: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 353: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 359: Durante el feriado, muchos visitan la Amazonía ecuatoriana Una experiencia inolvidable.
#
# results 360: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 361: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 364: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 368: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 371: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar tranquilo para visitar.
#
# results 373: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 374: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 376: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 379: Otavalo es conocido por su mercado indígena y su artesanía Ideal para el próximo feriado.
#
# results 380: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 382: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 386: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 389: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 394: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 402: Montañita se llena de surfistas durante los feriados
#
# results 405: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 407: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 408: Montañita se llena de surfistas durante los feriados
#
# results 409: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 411: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 412: Montañita se llena de surfistas durante los feriados Un lugar auténtico para visitar.
#
# results 420: Durante el feriado, muchos visitan la Amazonía ecuatoriana
#
# results 421: Montañita se llena de surfistas durante los feriados
#
# results 428: Guayaquil sorprende con su Malecón 2000 y vida nocturna Ideal para el próximo feriado.
#
# results 436: Mindo es famoso por el avistamiento de aves Ideal para el próximo feriado.
#
# results 439: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 440: Durante el feriado, muchos visitan la Amazonía ecuatoriana Ideal para el próximo feriado.
#
# results 442: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 446: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 447: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 449: Montañita se llena de surfistas durante los feriados Perfecto para canopy.
#
# results 450: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 456: El Parque Nacional Cajas invita a caminatas entre lagunas Ideal para el próximo feriado.
#
# results 458: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 469: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 472: Los turistas disfrutan las fiestas y gastronomía típica local Ideal para el próximo feriado.
#
# results 473: Cuenca deslumbra con su arquitectura colonial y gastronomía Ideal para el próximo feriado.
#
# results 474: Durante el feriado, muchos visitan la Amazonía ecuatoriana Un lugar increíble para visitar.
#
# results 475: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 479: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 481: El volcán Cotopaxi es un destino de senderismo popular Ideal para el próximo feriado.
#
# results 482: Montañita se llena de surfistas durante los feriados Una experiencia inolvidable.
#
# results 486: Quito tiene un centro histórico Patrimonio de la Humanidad Ideal para el próximo feriado.
#
# results 491: Ecuador es un país megadiverso, ideal para el turismo ecológico Ideal para el próximo feriado.
#
# results 492: Montañita se llena de surfistas durante los feriados Perfecto para senderismo.
#
# results 493: Montañita se llena de surfistas durante los feriados Ideal para el próximo feriado.
#
# results 494: Vilcabamba atrae visitantes interesados en longevidad y naturaleza Ideal para el próximo feriado.
#
# playas
# results 19: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 27: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 35: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 50: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 66: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 68: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 78: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 82: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 86: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 95: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 99: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para senderismo.
#
# results 102: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 119: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 123: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 134: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 150: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 163: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para surf.
#
# results 169: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 197: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 218: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 228: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 232: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 234: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 235: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 238: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 243: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 265: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar increíble para visitar.
#
# results 272: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 276: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar auténtico para visitar.
#
# results 297: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 298: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar famoso para visitar.
#
# results 320: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 321: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 326: La Ruta del Spondylus conecta playas famosas como Montañita Una experiencia inolvidable.
#
# results 327: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 369: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para avistamiento de aves.
#
# results 383: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 389: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 395: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 404: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar sorprendente para visitar.
#
# results 405: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# results 416: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para canopy.
#
# results 418: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 422: La Ruta del Spondylus conecta playas famosas como Montañita Un lugar tranquilo para visitar.
#
# results 429: La Ruta del Spondylus conecta playas famosas como Montañita
#
# results 466: La Ruta del Spondylus conecta playas famosas como Montañita Perfecto para rafting.
#
# results 479: La Ruta del Spondylus conecta playas famosas como Montañita Ideal para el próximo feriado.
#
# aventura
# results 37: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar sorprendente para visitar.
#
# results 53: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar famoso para visitar.
#
# results 61: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 76: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar famoso para visitar.
#
# results 84: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 89: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# results 90: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 96: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para avistamiento de aves.
#
# results 98: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# results 201: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 248: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 254: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 275: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para senderismo.
#
# results 277: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 283: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 310: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 313: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 329: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 331: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 336: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 338: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 376: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 388: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para surf.
#
# results 391: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 407: Baños de Agua Santa ofrece deportes de aventura como rafting Ideal para el próximo feriado.
#
# results 438: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 480: Baños de Agua Santa ofrece deportes de aventura como rafting
#
# results 483: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# results 484: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar famoso para visitar.
#
# results 489: Baños de Agua Santa ofrece deportes de aventura como rafting Una experiencia inolvidable.
#
# results 497: Baños de Agua Santa ofrece deportes de aventura como rafting Un lugar tranquilo para visitar.
#
# results 499: Baños de Agua Santa ofrece deportes de aventura como rafting Perfecto para canopy.
#
# Galápagos
# results 11: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 22: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 23: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 24: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 30: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 41: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 46: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar espectacular para visitar.
#
# results 80: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 83: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 93: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para rafting.
#
# results 124: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 127: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 138: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 172: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 226: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 242: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 287: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 294: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 303: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 305: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 307: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 337: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 349: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 358: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para rafting.
#
# results 393: Las Islas Galápagos atraen visitantes por su biodiversidad única Una experiencia inolvidable.
#
# results 398: Las Islas Galápagos atraen visitantes por su biodiversidad única
#
# results 442: Las Islas Galápagos atraen visitantes por su biodiversidad única Ideal para el próximo feriado.
#
# results 457: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 460: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar sorprendente para visitar.
#
# results 463: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar tranquilo para visitar.
#
# results 465: Las Islas Galápagos atraen visitantes por su biodiversidad única Un lugar espectacular para visitar.
#
# results 477: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para avistamiento de aves.
#
# results 498: Las Islas Galápagos atraen visitantes por su biodiversidad única Perfecto para canopy.
#
# laguna destaca
# results 1: La Laguna Quilotoa destaca por su color turquesa
#
# results 34: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 47: La Laguna Quilotoa destaca por su color turquesa Una experiencia inolvidable.
#
# results 60: La Laguna Quilotoa destaca por su color turquesa Perfecto para surf.
#
# results 62: La Laguna Quilotoa destaca por su color turquesa
#
# results 65: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 67: La Laguna Quilotoa destaca por su color turquesa Perfecto para canopy.
#
# results 81: La Laguna Quilotoa destaca por su color turquesa Un lugar espectacular para visitar.
#
# results 116: La Laguna Quilotoa destaca por su color turquesa
#
# results 141: La Laguna Quilotoa destaca por su color turquesa
#
# results 156: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 174: La Laguna Quilotoa destaca por su color turquesa Una experiencia inolvidable.
#
# results 205: La Laguna Quilotoa destaca por su color turquesa Perfecto para rafting.
#
# results 219: La Laguna Quilotoa destaca por su color turquesa Un lugar famoso para visitar.
#
# results 231: La Laguna Quilotoa destaca por su color turquesa Perfecto para avistamiento de aves.
#
# results 241: La Laguna Quilotoa destaca por su color turquesa Una experiencia inolvidable.
#
# results 258: La Laguna Quilotoa destaca por su color turquesa Perfecto para avistamiento de aves.
#
# results 260: La Laguna Quilotoa destaca por su color turquesa Perfecto para senderismo.
#
# results 264: La Laguna Quilotoa destaca por su color turquesa
#
# results 273: La Laguna Quilotoa destaca por su color turquesa Un lugar espectacular para visitar.
#
# results 316: La Laguna Quilotoa destaca por su color turquesa Una experiencia inolvidable.
#
# results 347: La Laguna Quilotoa destaca por su color turquesa Perfecto para rafting.
#
# results 355: La Laguna Quilotoa destaca por su color turquesa Perfecto para canopy.
#
# results 367: La Laguna Quilotoa destaca por su color turquesa Una experiencia inolvidable.
#
# results 377: La Laguna Quilotoa destaca por su color turquesa
#
# results 384: La Laguna Quilotoa destaca por su color turquesa Perfecto para avistamiento de aves.
#
# results 399: La Laguna Quilotoa destaca por su color turquesa Un lugar increíble para visitar.
#
# results 427: La Laguna Quilotoa destaca por su color turquesa
#
# results 437: La Laguna Quilotoa destaca por su color turquesa
#
# results 439: La Laguna Quilotoa destaca por su color turquesa Ideal para el próximo feriado.
#
# results 445: La Laguna Quilotoa destaca por su color turquesa
#
# results 451: La Laguna Quilotoa destaca por su color turquesa
#
#
# BÚSQUEDA ÍNDICE INVERTIDO en Corpus Grande:
#
# Quito
# [3, 259, 324, 390, 135, 72, 200, 74, 15, 16, 212, 468, 88, 290, 354, 38, 486, 103, 42, 237]
#
# Montañita
# [265, 267, 272, 19, 276, 27, 35, 297, 298, 299, 50, 311, 315, 317, 320, 321, 66, 322, 68, 326, 327, 78, 82, 86, 87, 95, 99, 102, 106, 369, 119, 123, 380, 125, 383, 386, 389, 134, 395, 145, 402, 404, 405, 150, 408, 412, 416, 418, 163, 421, 422, 169, 429, 177, 184, 449, 450, 197, 204, 208, 210, 466, 218, 475, 479, 482, 228, 232, 234, 235, 492, 493, 238, 243]
#
# feriado
# []
#
# playas
# [389, 134, 265, 395, 272, 19, 276, 404, 150, 405, 27, 416, 418, 35, 163, 422, 169, 297, 298, 429, 50, 320, 321, 66, 68, 197, 326, 327, 78, 82, 466, 86, 218, 95, 479, 99, 228, 102, 232, 234, 235, 238, 369, 243, 119, 123, 383]
#
# aventura
# [388, 391, 275, 277, 407, 283, 37, 53, 310, 438, 313, 61, 201, 329, 331, 76, 336, 338, 84, 89, 90, 96, 480, 98, 483, 376, 484, 489, 497, 499, 248, 254]
#
# Galápagos
# [393, 138, 11, 398, 22, 23, 24, 30, 287, 294, 41, 172, 46, 303, 305, 307, 442, 457, 460, 463, 80, 337, 465, 83, 93, 349, 477, 226, 358, 242, 498, 124, 127]
#
# laguna destaca
# [384, 1, 258, 260, 264, 141, 399, 273, 156, 34, 427, 174, 47, 437, 439, 60, 316, 445, 62, 65, 67, 451, 205, 81, 219, 347, 355, 231, 367, 241, 116, 377]
#
#              Query          Corpus  Linear Search Time (s)  \
# 0            Quito  Corpus Pequeño                0.000021
# 1        Montañita  Corpus Pequeño                0.000016
# 2          feriado  Corpus Pequeño                0.000015
# 3           playas  Corpus Pequeño                0.000014
# 4         aventura  Corpus Pequeño                0.000015
# 5        Galápagos  Corpus Pequeño                0.000014
# 6   laguna destaca  Corpus Pequeño                0.000015
# 7            Quito   Corpus Grande                0.000420
# 8        Montañita   Corpus Grande                0.000382
# 9          feriado   Corpus Grande                0.000495
# 10          playas   Corpus Grande                0.000414
# 11        aventura   Corpus Grande                0.000425
# 12       Galápagos   Corpus Grande                0.000366
# 13  laguna destaca   Corpus Grande                0.000368
#
#     Inverted Search Time (s)     Speedup
# 0                   0.000005    4.160000
# 1                   0.000002    6.999996
# 2                   0.000002    9.312504
# 3                   0.000002    9.666663
# 4                   0.000001   10.785717
# 5                   0.000001    9.600009
# 6                   0.000002    7.249998
# 7                   0.000006   72.482775
# 8                   0.000009   44.406977
# 9                   0.000005  105.276609
# 10                  0.000008   54.513160
# 11                  0.000006   73.258614
# 12                  0.000006   64.245617
# 13                  0.000008   48.486844
